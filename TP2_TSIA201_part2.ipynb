# %% [markdown]
# EXERCICE 2

# %% [markdown]
# QUESTION 1

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread('lena.jpg')
plt.imshow(img)
plt.set_cmap('gray')
plt.show()

# %% [markdown]
# QUESTION 2

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\alix\documents\anaconda\lib\site-packages (4.5.4.58)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\alix\documents\anaconda\lib\site-packages (from opencv-python) (1.18.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import wtt
import pywt
import numpy as np

wav = 'db3'
NLEV = 4
filter_bank = pywt.Wavelet(wav)
coeffs = pywt.wavedec2(img, filter_bank, mode='per', level=NLEV)
print(coeffs[len(coeffs)-1][0].shape)
arr4 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, 'Scaled DWT coeffs')
plt.figure()
plt.imshow(np.abs(arr4/arr4.max()))
plt.set_cmap('jet')
plt.title('Unscaled DWT coefficients')
plt.show()
decoded = pywt.waverec2(coeffs, filter_bank, mode='per')
plt.imshow(np.uint8(decoded))
plt.title('Inverse DWT')
plt.set_cmap('gray')
plt.show()
# Out:
# (256, 256)

# %%
NLEV = 2
filter_bank = pywt.Wavelet(wav)
coeffs = pywt.wavedec2(img, filter_bank, mode='per', level=NLEV)
print(coeffs[len(coeffs)-1][0].shape)
arr2 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, 'Scaled DWT coeffs')
plt.figure()
plt.imshow(np.abs(arr2/arr2.max()))
plt.set_cmap('jet')
plt.title('Unscaled DWT coefficients')
plt.show()
decoded = pywt.waverec2(coeffs, filter_bank, mode='per')
plt.imshow(np.uint8(decoded))
plt.title('Inverse DWT')
plt.set_cmap('gray')
plt.show()
# Out:
# (256, 256)

# %%
NLEV = 1
filter_bank = pywt.Wavelet(wav)
coeffs = pywt.wavedec2(img, filter_bank, mode='per', level=NLEV)
print(coeffs[len(coeffs)-1][0].shape)
arr1 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, 'Scaled DWT coeffs')
plt.figure()
plt.imshow(np.abs(arr1/arr1.max()))
plt.set_cmap('jet')
plt.title('Unscaled DWT coefficients')
plt.show()
decoded = pywt.waverec2(coeffs, filter_bank, mode='per')
plt.imshow(np.uint8(decoded))
plt.title('Inverse DWT')
plt.set_cmap('gray')
plt.show()
# Out:
# (256, 256)

# %%
plt.title(f"NLEV = 4, histogramme")
plt.hist(arr4)
plt.show()
plt.title(f" NLEV = 2, histogramme")
plt.hist(arr2)
plt.show()
plt.title(f" NLEV = 1, histogramme")
plt.hist(arr1)
plt.show()

# %% [markdown]
# On remarque qu'au plus NLEV est élevé, au plus les histogrammes sont concentrés autour de 0

# %% [markdown]
# QUESTION 3

# %%
wav = 'bior4.4'
NLEV = 4
filter_bank = pywt.Wavelet(wav)
coeffs = pywt.wavedec2(img, filter_bank, mode='per', level=NLEV)
print(coeffs[len(coeffs)-1][0].shape)
arr4 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, 'Scaled DWT coeffs')
plt.figure()
plt.imshow(np.abs(arr4/arr4.max()))
plt.set_cmap('jet')
plt.title('Unscaled DWT coefficients')
plt.show()
decoded = pywt.waverec2(coeffs, filter_bank, mode='per')
plt.imshow(np.uint8(decoded))
plt.title('Inverse DWT')
plt.set_cmap('gray')
plt.show()
# Out:
# (256, 256)

# %%
NLEV = 2
filter_bank = pywt.Wavelet(wav)
coeffs = pywt.wavedec2(img, filter_bank, mode='per', level=NLEV)
print(coeffs[len(coeffs)-1][0].shape)
arr2 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, 'Scaled DWT coeffs')
plt.figure()
plt.imshow(np.abs(arr2/arr2.max()))
plt.set_cmap('jet')
plt.title('Unscaled DWT coefficients')
plt.show()
decoded = pywt.waverec2(coeffs, filter_bank, mode='per')
plt.imshow(np.uint8(decoded))
plt.title('Inverse DWT')
plt.set_cmap('gray')
plt.show()
# Out:
# (256, 256)

# %%
NLEV = 1
filter_bank = pywt.Wavelet(wav)
coeffs = pywt.wavedec2(img, filter_bank, mode='per', level=NLEV)
print(coeffs[len(coeffs)-1][0].shape)
arr1 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, 'Scaled DWT coeffs')
plt.figure()
plt.imshow(np.abs(arr1/arr1.max()))
plt.set_cmap('jet')
plt.title('Unscaled DWT coefficients')
plt.show()
decoded = pywt.waverec2(coeffs, filter_bank, mode='per')
plt.imshow(np.uint8(decoded))
plt.title('Inverse DWT')
plt.set_cmap('gray')
plt.show()
# Out:
# (256, 256)

# %%
plt.title(f"NLEV = 4, histogramme")
plt.hist(arr4)
plt.show()
plt.title(f" NLEV = 2, histogramme")
plt.hist(arr2)
plt.show()
plt.title(f" NLEV = 1, histogramme")
plt.hist(arr1)
plt.show()

# %% [markdown]
# Ici on rencontre la même situation que précédement, les histogrammes sont davantages concentrés autour de 0 lorsque NLEV est grand

# %% [markdown]
# QUESTIONS 4 ET 5

# %%
from scipy.signal import freqz
w_low, h_low = freqz(h0)


plt.plot(w_low ,np.abs(h_low), label='low pass')
plt.legend()
plt.show()

# %%
w_high, h_high = freqz(h1)
plt.plot(w_high,np.abs(h_high), label="high pass")
plt.legend()
plt.show()

# %% [markdown]
# QUESTION 6
